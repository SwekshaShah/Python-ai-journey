# %%
name="Sweksha Shah"
age= 18
height= 5.8
is_student= True
middle_name= None
frequency= 3 + 4j

for i in [name,age,height,is_student,middle_name,frequency]:
  print(f"Value:{i!r:<20} type:{type(i).__name__}")
# Out:
# Value:'Sweksha Shah'       type:str
# Value:18                   type:int
# Value:5.8                  type:float
# Value:True                 type:bool
# Value:None                 type:NoneType
# Value:(3+4j)               type:complex

# %% [markdown]
# f=

# %%
print(f"hello world")
# Out:
# hello world

# %%
name="Sweksha Shah"
age= 18
print("hello ,i am"+ name + "and i am  " + str(age) + " years old")
# Out:
# hello ,i amSweksha Shahand i am  18 years old

# %%
name="Sweksha Shah"
age= 18
print(f"hello ,i am {name}, and i am {age} years old")
# Out:
# hello ,i am Sweksha Shah, and i am 18 years old

# %%
name="sweksha"
lucky_number= 15
print("hello, my name is " + name + " and my lucky number is " + str(lucky_number))
# Out:
# hello, my name is sweksha and my lucky number is 15

# %%
name="sweksha"
lucky_number= 15
print(f"hello, my name is {name} and my lucky number is {lucky_number}.")
# Out:
# hello, my name is sweksha and my lucky number is 15.

# %%
print(type("hello"))
# Out:
# <class 'str'>

# %%
print(isinstance("hello",int))
print(isinstance(24.1,float))
# Out:
# False
# True

# %%
print(True + True)
# Out:
# 2

# %%
print(type(True) .__name__)
# Out:
# bool

# %%
a=10
b=12
print(a,b)
# Out:
# 10 12

# %% [markdown]
# swap two number

# %%
a=10
b=20
a,b= b,a
print(a,b)
# Out:
# 20 10

# %% [markdown]
# by the use of three variable

# %%
a=10
b=20
c=a
a=b
b=c
print(a,b)
# Out:
# 20 10

# %%
print(10+3)
# Out:
# 13

# %%
print(3-1)
# Out:
# 2

# %%
print(str(365//7) + "week")
# Out:
# 52week

# %%
print(2**3)
# Out:
# 8

# %%
x=5
print(x==5)
# Out:
# True

# %%
age=21
has_id= True
can_enter= age>=18 and has_id
print(can_enter)
# Out:
# True

# %%
print("default" or 0)
# Out:
# default

# %%
print(None or 42)
# Out:
# 42

# %% [markdown]
# it always take first one

# %%
print("hello" or "bye")
# Out:
# hello

# %%
print(0 and "default")
# Out:
# 0

# %%
print("default" and 0)
# Out:
# 0

# %%
print(42 or None)
# Out:
# 42

# %%
name= input("Name: ") or "Anonymous"
print(name)
# Out:
# Name:
# Anonymous

# %%
name= input("Name: ") and "Anonymous"
print(name)
# Out:
# Name:

# %%
age=int(input("enter your age"))
print(f"next year you will be {age+1}")
# Out:
# enter your age18
# next year you will be 19

# %%
age= input("enter your age")
print(int(age)+1)
# Out:
# enter your age18
# 19

# %%
print(True+1)
# Out:
# 2
